# %%
import numpy as np 
import matplotlib.pyplot as plt
import random
import csv

from ipynb.fs.full.pb_private import bootstrap
# Out:
# 193.23921959394514 2.418551383396486

# %%
def estimator_mean(data):
    return np.mean(data)

def estimator_var(data):
    return np.var(data)

# %%
B =  500 #bootstrap iterations
    
header = ['n', 'T', 'true_parameter', 'estimator_mean', 'estimator_variance']

T = 1000 #trials
list_of_n = [250, 500, 750, 1000, 2500, 5000]

true_theta = 4

R = [0,10]

with open('pb_poisson_DP.csv', 'w', encoding='UTF8', newline='') as file:
    writer = csv.writer(file)

    # write the header
    writer.writerow(header)

    for n in list_of_n:
        for t in range(T):
            data = np.random.poisson(true_theta, n)
            theta, sigma_sq = bootstrap(B, data, estimator_mean, R)
            row = [n, t, true_theta, theta, sigma_sq]
        
            # write the data
            writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#      19 for t in range(T):
#      20     data = np.random.poisson(true_theta, n)
# ---> 21     theta, sigma_sq = bootstrap(B, data, estimator_mean, R)
#      22     row = [n, t, true_theta, theta, sigma_sq]
#      24     # write the data
#
# File ~\Desktop\thesisspring22\with DP\parametric_bootstrap\pb_private.ipynb:71, in bootstrap(B, data, estimator_func, R)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import numpy as np \n",
#      10     "import matplotlib.pyplot as plt\n",
#      11     "import random\n",
#      12     "import csv"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 2,
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "def PrivateGaussianEst(X, epsilon, R, estimator_func):\n",
#      22     "    \"\"\"\n",
#      23     "    INPUT\n",
#      24     "    X: data sample from a Gaussian of unknown mean and std\n",
#      25     "    epsilon: DP privacy parameter\n",
#      26     "    R: data range (supplied by analyst)\n",
#      27     "\n",
#      28     "    OUTPUT\n",
#      29     "    mu_hat_priv: private estimate of the mean\n",
#      30     "    sigma_hat_priv: private estimate of the mean\n",
#      31     "\n",
#      32     "    (note: this uses a 50-50 budget split between mu and sigma priv estimates)\n",
#      33     "    \"\"\"\n",
#      34     "    n = len(X)\n",
#      35     "    \n",
#      36     "    #clamp data to given range R\n",
#      37     "    X[X<R[0]] = R[0]\n",
#      38     "    X[X>R[1]] = R[1]\n",
#      39     "\n",
#      40     "    #privately estimate mu using half of the budget\n",
#      41     "    Delta_mu = 1/n * (R[1]-R[0])\n",
#      42     "    mu_noise = np.random.laplace(loc=0, scale=Delta_mu/(epsilon/2))\n",
#      43     "    mu_hat_priv =  estimator_func(X) + mu_noise\n",
#      44     "\n",
#      45     "    #privately estimate sigma using half of the budget\n",
#      46     "    Delta_sigma = 2/n * (R[1]-R[0])\n",
#      47     "    sigma_noise = np.random.laplace(loc=0, scale=Delta_sigma/(epsilon/2))\n",
#      48     "    sigma_hat_priv_tmp = 1/n * np.sum(np.abs(X-np.mean(X))) + sigma_noise\n",
#      49     "    sigma_hat_priv = np.sqrt(np.pi/2) * max(1e-8, sigma_hat_priv_tmp)  # see Du et al. 2020\n",
#      50     "\n",
#      51     "    return mu_hat_priv, sigma_hat_priv"
#      52    ]
#      53   },
#      54   {
#      55    "cell_type": "code",
#      56    "execution_count": 3,
#      57    "metadata": {
#      58     "jupyter": {
#      59      "source_hidden": true
#      60     }
#      61    },
#      62    "outputs": [],
#      63    "source": [
#      64     "def applyDP(data, theta_hat):\n",
#      65     "    \n",
#      66     "    epsilon = 0.05\n",
#      67     "    Delta = (data.max() - data.min())/ len(data)\n",
#      68     "\n",
#      69     "    # we need to define the scale parameter of the Laplace noise (see notes)\n",
#      70     "    b = Delta/epsilon\n",
# ---> 71     "\n",
#      72     "    # sample the laplace noise \n",
#      73     "    noise = np.random.laplace(loc=0, scale=b)\n",
#      74     "    # print(\"noise =\", noise)\n",
#      75     "\n",
#      76     "    # add the noise to the average we found\n",
#      77     "    theta_hat_DP = theta_hat + noise\n",
#      78     "    \n",
#      79     "\n",
#      80     "    return theta_hat_DP"
#      81    ]
#      82   },
#      83   {
#      84    "cell_type": "code",
#      85    "execution_count": 4,
#      86    "metadata": {},
#      87    "outputs": [],
#      88    "source": [
#      89     "def bootstrap(B, data, estimator_func, R):\n",
#      90     "    bootstrap_vec = []\n",
#      91     "    \n",
#      92     "    epsilon = 1\n",
#      93     "    theta_hat_priv, sigma_hat_priv = PrivateGaussianEst(data, epsilon, R, estimator_func)\n",
#      94     "    \n",
#      95     "    \n",
#      96     "    #estimator func: input: data, privacy budget, bounds, .output: mean and sd\n",
#      97     "    \n",
#      98     "    for b in range(B):\n",
#      99     "        data_tilde = np.random.normal(theta_hat_priv, sigma_hat_priv, len(data)) #sample with theta_hat_DP instead?\n",
#     100     "        \n",
#     101     "        theta_tilde_priv, sigma_tilde_priv = PrivateGaussianEst(data_tilde, epsilon, R, estimator_func)\n",
#     102     "        \n",
#     103     "        bootstrap_vec.append(theta_tilde_priv)\n",
#     104     "    sigma_sq = np.var(bootstrap_vec)    \n",
#     105     "        \n",
#     106     "    return (theta_hat_priv, sigma_sq)"
#     107    ]
#     108   },
#     109   {
#     110    "cell_type": "code",
#     111    "execution_count": 6,
#     112    "metadata": {},
#     113    "outputs": [
#     114     {
#     115      "name": "stdout",
#     116      "output_type": "stream",
#     117      "text": [
#     118       "192.7090792636657 6.824988496704405\n"
#     119      ]
#     120     }
#     121    ],
#     122    "source": [
#     123     "data = np.random.normal(190, 30, 100)\n",
#     124     "B = 10\n",
#     125     "\n",
#     126     "R = [160, 220]\n",
#     127     "\n",
#     128     "def estimator_mean(data):\n",
#     129     "    return np.mean(data)\n",
#     130     "\n",
#     131     "(theta_hat_priv, sigma_sq) = bootstrap(B, data, estimator_mean, R)\n",
#     132     "print(theta_hat_priv, sigma_sq)"
#     133    ]
#     134   },
#     135   {
#     136    "cell_type": "code",
#     137    "execution_count": null,
#     138    "metadata": {},
#     139    "outputs": [],
#     140    "source": []
#     141   }
#     142  ],
#     143  "metadata": {
#     144   "kernelspec": {
#     145    "display_name": "Python 3 (ipykernel)",
#     146    "language": "python",
#     147    "name": "python3"
#     148   },
#     149   "language_info": {
#     150    "codemirror_mode": {
#     151     "name": "ipython",
#     152     "version": 3
#     153    },
#     154    "file_extension": ".py",
#     155    "mimetype": "text/x-python",
#     156    "name": "python",
#     157    "nbconvert_exporter": "python",
#     158    "pygments_lexer": "ipython3",
#     159    "version": "3.8.6"
#     160   }
#     161  },
#     162  "nbformat": 4,
#     163  "nbformat_minor": 4
#     164 }
#
# KeyboardInterrupt:
